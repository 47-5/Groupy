# %%
from gp_3x_calculator import Calculator  # Import Calculator class

calculator = Calculator()  # Instantiate a Calculator object

# Setting debug=True requires the program to print the number of groups at the same time
result = calculator.calculate_a_mol('CC1(C2)CC(C3)CC2CC3(C)C1', debug=True) 

print(result)  # Print calculation results
# Out:
# {'f_001': 2, 'f_168': 6, 'f_169': 2, 'f_170': 2, 's_099': 2, 't_022': 2, 't_023': 2}
# {'smiles': 'CC12CC3CC(C1)CC(C)(C3)C2', 'molar_mass': 164.29200000000017, 'flash_point/K': 293.598, 'Tm/K': 264.876, 'Tb/K': 466.058, 'Tc/K': 692.493, 'Pc/bar': 22.9671, 'Vc/(cm3/mol)': 602.96, 'density/(g/cm3)': 0.939, 'delta_G/(KJ/mol)': 100.491, 'delta_Hf/(KJ/mol)': -180.571, 'delta_Hvap/(KJ/mol)': 51.399, 'delta_Hfus/(KJ/mol)': 5.219, 'molar_volume/(cm3/mol)(default298K)': 0.175, 'delta_Hc/(KJ/mol)': 6983.849, 'mass_calorific_value_h/(MJ/kg)': 42.509, 'ISP': 337.822, 'note': 'CC12CC3CC(C1)CC(C)(C3)C2 at 298K'}

# %%
import os
from gp_3x_calculator import Calculator  # Import Calculator class

calculator = Calculator()  # Instantiate a Calculator object

input_file_path = os.path.join('gp_3x_test_mol', 'SMILES.txt')  # Define the input file path
output_file_path = os.path.join('result.csv')  # Define the output file path
calculator.calculate_mols(input_file_path, output_file_path)  # Start
# Out:
# reading input file...
# reading completed，A total of 386 molecules detected, start calculating properties...
# start calculating...
# 100%|████████████████████████████████████████████████████████████████████████████████| 386/386 [00:08<00:00, 44.09it/s]
# calculation completed!
# start to export result to result.csv ...
# Done!
#                        smiles  molar_mass  flash_point/K     Tm/K     Tb/K  \
# 0                    CCCCCCCC     114.232        283.314  164.048  405.911
# 1                    CCCC(C)C      86.178        254.043  123.059  327.848
# 2                  CCC(C)(C)C      86.178        245.855  147.423  315.663
# 3                     C=CCCCC      84.162        257.475  130.515  339.222
# 4                   C/C=C/CCC      84.162        255.581  152.375  343.070
# ..                        ...         ...            ...      ...      ...
# 381  Cc1c(C)c2ccccc2c2ccccc12     206.288        451.126  383.938  625.019
# ...

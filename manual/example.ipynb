# %%
from groupy.gp_calculator import Calculator

c = Calculator()
result = c.calculate_a_mol('CC1(C2)CC(C3)CC2CC3(C)C1', debug=True)

print(result)
# Out:
# {'f_001': 2, 'f_168': 6, 'f_169': 2, 'f_170': 2, 's_099': 2, 't_022': 2, 't_023': 2}
# {'smiles': 'CC12CC3CC(C1)CC(C)(C3)C2', 'molar_mass': 164.29200000000017, 'flash_point/K': 293.598, 'Tm/K': 264.876, 'Tb/K': 466.058, 'Tc/K': 692.493, 'Pc/bar': 22.9671, 'Vc/(cm3/mol)': 602.96, 'density/(g/cm3)': 0.939, 'delta_G/(KJ/mol)': 100.491, 'delta_Hf/(KJ/mol)': -180.571, 'delta_Hvap/(KJ/mol)': 51.399, 'delta_Hfus/(KJ/mol)': 5.219, 'molar_volume/(cm3/mol)(default298K)': 0.175, 'delta_Hc/(KJ/mol)': 6983.849, 'mass_calorific_value_h/(MJ/kg)': 42.509, 'ISP': 337.822, 'note': 'CC12CC3CC(C1)CC(C)(C3)C2 at 298K'}

# %%
import os
from groupy.gp_calculator import Calculator

c = Calculator()

input_file_path = os.path.join('example', 'main_3', 'SMILES.txt')
output_file_path = os.path.join('result.csv')
c.calculate_mols(input_file_path, output_file_path)
# Out:
# reading input file...
# reading completed，A total of 386 molecules detected, start calculating properties...
# start calculating...
# 100%|████████████████████████████████████████████████████████████████████████████████| 386/386 [00:09<00:00, 41.40it/s]
# calculation completed!
# start to export result to result.csv ...
# Done!
#                        smiles  molar_mass  ...      ISP                              note
# 0                    CCCCCCCC     114.232  ...  339.888                  CCCCCCCC at 298K
# 1                    CCCC(C)C      86.178  ...  339.750                  CCCC(C)C at 298K
# 2                  CCC(C)(C)C      86.178  ...  339.483                CCC(C)(C)C at 298K
# 3                     C=CCCCC      84.162  ...  342.958                   C=CCCCC at 298K
# 4                   C/C=C/CCC      84.162  ...  342.538                 C/C=C/CCC at 298K
# ..                        ...         ...  ...      ...                               ...
# ...
